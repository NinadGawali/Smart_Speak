# %%
import os

print(os.path.exists("../models/CNN_model.json"))
print(os.path.exists("../models/CNN_model_weights.h5"))
# Out:
# True
# True

# %%
from load_model import load_cnn_model

model = load_cnn_model(
    "../models/CNN_model.json",
    "../models/CNN_model_weights.h5"
)

model.summary()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[1], line 3
#       1 from load_model import load_cnn_model
# ----> 3 model = load_cnn_model(
#       4     "../models/CNN_model.json",
#       5     "../models/CNN_model_weights.h5"
#       6 )
#       8 model.summary()
#
# File ~\emotion_cnn_project\src\load_model.py:7, in load_cnn_model(json_path, weights_path)
#       4 def load_cnn_model(json_path, weights_path):
#       5
#       6     # Enable legacy serialization compatibility
# ----> 7     tf.keras.config.enable_legacy_serialization()
#       9     with open(json_path, "r") as json_file:
#      10         model_json = json_file.read()
#
# AttributeError: module 'keras.config' has no attribute 'enable_legacy_serialization'

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.19.0
