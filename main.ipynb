# %%
from src.inference import predict

emotion, confidence = predict("sample.wav")

print("Predicted Class:", emotion)
print("Confidence:", confidence)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from src.inference import predict
#       3 emotion, confidence = predict("sample.wav")
#       5 print("Predicted Class:", emotion)
#
# ModuleNotFoundError: No module named 'src.inference'
